# %%
from src.crea.clustering.cluster import *
from src.crea.fca.similarity import *
from src.crea.fca.plot import *
from concepts import Context

# %% [markdown]
# # Strategy Bin High β = 1.0, k = 52

# %%
# compute similarity matrix from ctx
ctx = Context.fromfile("/Users/monicasen/PycharmProjects/topic-modeling/datasets/rychkova_papers/matrix/rychkova_abstracts_lemmas_en_filtered__20250822-064803/bin_high_10/cxt")
sim_matrix = compute_conceptual_similarity_matrix(ctx)

# hca clustering
Z, _, _ = compute_hierarchical_clusters(sim_matrix)

# %%
rows = []
k_min, k_max = 4, 80

for k in range(k_min, k_max + 1, 5):
    sil, labels_k = compute_silhouette_for_k(sim_matrix, Z, k=k)
    stats = cluster_stats(labels_k)
    rows.append({
        "k": k,
        "silhouette": sil,
        **stats
    })

sil_df = pd.DataFrame(rows)
sil_df
# Out:
#      k  silhouette  n_clusters  min_size  max_size  singleton_ratio  \
# 0    4    0.076175           4         7       390         0.000000
# 1    9    0.069783           9         2       329         0.000000
# 2   14    0.085209          12         2       270         0.000000
# 3   19    0.122766          18         2       210         0.000000
# 4   24    0.166172          24         2       204         0.000000
# 5   29    0.166021          27         1       204         0.002278
# 6   34    0.190149          33         1       183         0.002278
# 7   39    0.211097          38         1       180         0.002278
# 8   44    0.213676          40         1       180         0.004556
# 9   49    0.213676          40         1       180         0.004556
# 10  54    0.402961          52         1        31         0.006834
# 11  59    0.413500          59         1        31         0.018223
# 12  64    0.413241          60         1        31         0.020501
# ...

# %%
plot_silhouette_curve(sil_df)

# %%
# number of clusters
k = 52

# hca clustering
Z, clusters, labels = compute_hierarchical_clusters(sim_matrix, n_clusters=k)

plot_dendrogram(Z, labels, title="Dendrogram")

# %%
pd.set_option('display.max_colwidth', None)

df_clusters = clusters_to_df(clusters)
display(df_clusters)
# Out:
#     cluster_id  n_terms  \
# 0           30       31
# 1           37       27
# 2           33       26
# 3           35       23
# 4           42       20
# 5           34       18
# 6           29       16
# 7           31       15
# 8           49       15
# 9            7       14
# 10          38       14
# 11          27       13
# 12          32       13
# 13          48       13
# 14          21       12
# 15          24       12
# 16          43       12
# 17          36       11
# 18          52       11
# 19          20       10
# 20          23       10
# 21          40        9
# 22          44        9
# 23           5        8
# 24          26        8
# 25          25        6
# 26          51        6
# 27          47        5
# 28          19        4
# 29           4        3
# 30          14        3
# 31          28        3
# 32          41        3
# 33          45        3
# 34           1        2
# 35           2        2
# 36           6        2
# ...

# %% [markdown]
# # Strategy Bin High β = 1.5, k = 43

# %%
# compute similarity matrix from ctx
ctx = Context.fromfile("/Users/monicasen/PycharmProjects/topic-modeling/datasets/rychkova_papers/matrix/rychkova_abstracts_lemmas_en_filtered__20250822-064803/bin_high_15/cxt")
sim_matrix = compute_conceptual_similarity_matrix(ctx)

# hca clustering
Z, _, _ = compute_hierarchical_clusters(sim_matrix)

# %%
rows = []
k_min, k_max = 4, 80

for k in range(k_min, k_max + 1, 5):
    sil, labels_k = compute_silhouette_for_k(sim_matrix, Z, k=k)
    stats = cluster_stats(labels_k)
    rows.append({
        "k": k,
        "silhouette": sil,
        **stats
    })

sil_df = pd.DataFrame(rows)
sil_df
# Out:
#      k  silhouette  n_clusters  min_size  max_size  singleton_ratio  \
# 0    4    0.087638           4         6       382         0.000000
# 1    9    0.085084           8         4       357         0.000000
# 2   14    0.115705          13         4       243         0.000000
# 3   19    0.190257          19         4       209         0.000000
# 4   24    0.222546          24         2       196         0.000000
# 5   29    0.246144          28         2       182         0.000000
# 6   34    0.252682          32         2       166         0.000000
# 7   39    0.252682          32         2       166         0.000000
# 8   44    0.384323          43         2        49         0.000000
# 9   49    0.398051          47         2        49         0.000000
# 10  54    0.410288          53         1        49         0.002278
# 11  59    0.410288          53         1        49         0.002278
# 12  64    0.410288          53         1        49         0.002278
# ...

# %%
# number of clusters
k = 43

# hca clustering
Z, clusters, labels = compute_hierarchical_clusters(sim_matrix, n_clusters=k)

# plot_dendrogram(Z, labels, title="Dendrogram")

pd.set_option('display.max_colwidth', None)

df_clusters = clusters_to_df(clusters)
display(df_clusters)
# Out:
#     cluster_id  n_terms  \
# 0           24       49
# 1           30       22
# 2           27       18
# 3           19       17
# 4           28       17
# 5           13       16
# 6           23       16
# 7           25       16
# 8           26       16
# 9           39       16
# 10           6       14
# 11          20       14
# 12          22       14
# 13          42       14
# 14          43       14
# 15          21       13
# 16          29       13
# 17          35       13
# 18          34       12
# 19          37       12
# 20           7       11
# 21          38       11
# 22          40       10
# 23          41       10
# 24           2        8
# 25          31        7
# 26           3        5
# 27           9        4
# 28          32        4
# 29          33        4
# 30           4        3
# 31          14        3
# 32          18        3
# 33           1        2
# 34           5        2
# 35           8        2
# 36          10        2
# ...

# %% [markdown]
# # Strategy Bin High β = 1.75, k = 44

# %%
# compute similarity matrix from ctx
ctx = Context.fromfile("/Users/monicasen/PycharmProjects/topic-modeling/datasets/rychkova_papers/matrix/rychkova_abstracts_lemmas_en_filtered__20250822-064803/bin_high_175/cxt")
sim_matrix = compute_conceptual_similarity_matrix(ctx)

# hca clustering
Z, _, _ = compute_hierarchical_clusters(sim_matrix)

# %%
rows = []
k_min, k_max = 4, 80

for k in range(k_min, k_max + 1, 5):
    sil, labels_k = compute_silhouette_for_k(sim_matrix, Z, k=k)
    stats = cluster_stats(labels_k)
    rows.append({
        "k": k,
        "silhouette": sil,
        **stats
    })

sil_df = pd.DataFrame(rows)
sil_df
# Out:
#      k  silhouette  n_clusters  min_size  max_size  singleton_ratio  \
# 0    4    0.058686           4        10       329         0.000000
# 1    9    0.101881           8        10       257         0.000000
# 2   14    0.143680          12         9       204         0.000000
# 3   19    0.240447          19         9       101         0.000000
# 4   24    0.266903          22         4       101         0.000000
# 5   29    0.306336          27         4        93         0.000000
# 6   34    0.359881          33         2        79         0.000000
# 7   39    0.359881          33         2        79         0.000000
# 8   44    0.457262          44         2        34         0.000000
# 9   49    0.465266          47         2        34         0.000000
# 10  54    0.465266          47         2        34         0.000000
# 11  59    0.529081          56         1        20         0.002278
# 12  64    0.529081          56         1        20         0.002278
# ...

# %%
# number of clusters
k = 44

# hca clustering
Z, clusters, labels = compute_hierarchical_clusters(sim_matrix, n_clusters=k)

# plot_dendrogram(Z, labels, title="Dendrogram")

pd.set_option('display.max_colwidth', None)

df_clusters = clusters_to_df(clusters)
display(df_clusters)
# Out:
#     cluster_id  n_terms  \
# 0           23       34
# 1           24       23
# 2           16       20
# 3           35       19
# 4           42       17
# 5           32       15
# 6           22       14
# 7           30       14
# 8           13       13
# 9           34       13
# 10           3       12
# 11           7       12
# 12          15       12
# 13          18       12
# 14          29       12
# 15          44       12
# 16           8       11
# 17           5       10
# 18          10       10
# 19          12       10
# 20          37       10
# 21           1        9
# 22          25        9
# 23          27        9
# 24          31        9
# 25          36        9
# 26          19        8
# 27          21        8
# 28          41        8
# 29          20        7
# 30          33        7
# 31          39        7
# 32           9        6
# 33          11        6
# 34          17        6
# 35          28        5
# 36          26        4
# ...

# %% [markdown]
# # Strategy Bin High β = 2.00, k = 38

# %%
# compute similarity matrix from ctx
ctx = Context.fromfile("/Users/monicasen/PycharmProjects/topic-modeling/datasets/rychkova_papers/matrix/rychkova_abstracts_lemmas_en_filtered__20250822-064803/bin_high_20/cxt")
sim_matrix = compute_conceptual_similarity_matrix(ctx)

# hca clustering
Z, _, _ = compute_hierarchical_clusters(sim_matrix)

# %%
rows = []
k_min, k_max = 4, 80

for k in range(k_min, k_max + 1, 5):
    sil, labels_k = compute_silhouette_for_k(sim_matrix, Z, k=k)
    stats = cluster_stats(labels_k)
    rows.append({
        "k": k,
        "silhouette": sil,
        **stats
    })

sil_df = pd.DataFrame(rows)
sil_df
# Out:
#      k  silhouette  n_clusters  min_size  max_size  singleton_ratio  \
# 0    4    0.065604           4        14       383         0.000000
# 1    9    0.104490           9         7       295         0.000000
# 2   14    0.158963          14         7       226         0.000000
# 3   19    0.168487          15         7       226         0.000000
# 4   24    0.217131          20         6       185         0.000000
# 5   29    0.326252          27         6       133         0.000000
# 6   34    0.326252          27         6       133         0.000000
# 7   39    0.464905          38         3        32         0.000000
# 8   44    0.479742          43         2        32         0.000000
# 9   49    0.484542          45         2        32         0.000000
# 10  54    0.547748          54         2        19         0.000000
# 11  59    0.547748          54         2        19         0.000000
# 12  64    0.573387          62         1        19         0.002278
# ...

# %%
# number of clusters
k = 38

# hca clustering
Z, clusters, labels = compute_hierarchical_clusters(sim_matrix, n_clusters=k)

# plot_dendrogram(Z, labels, title="Dendrogram")

pd.set_option('display.max_colwidth', None)

df_clusters = clusters_to_df(clusters)
display(df_clusters)
# Out:
#     cluster_id  n_terms  \
# 0           11       32
# 1           22       19
# 2           18       18
# 3            4       17
# 4           13       15
# 5           25       15
# 6            2       14
# 7            5       14
# 8           20       14
# 9           21       14
# 10          30       14
# 11          33       14
# 12          36       14
# 13           9       13
# 14          19       13
# 15          24       12
# 16          31       12
# 17          34       12
# 18           7       11
# 19          14       11
# 20          38       11
# 21           1       10
# 22           6       10
# 23           8       10
# 24          23       10
# 25          32       10
# 26          12        9
# 27          15        9
# 28          26        9
# 29          27        9
# 30          16        7
# 31          37        7
# 32          17        6
# 33          28        6
# 34          29        6
# 35          35        6
# 36           3        3
# ...

# %% [markdown]
# # Strategy Bin High β = 2.00, k = 8

# %%
# number of clusters
k = 8

# hca clustering
Z, clusters, labels = compute_hierarchical_clusters(sim_matrix, n_clusters=k)

# plot_dendrogram(Z, labels, title="Dendrogram")

pd.set_option('display.max_colwidth', None)

df_clusters = clusters_to_df(clusters)
display(df_clusters)
# Out:
#    cluster_id  n_terms  \
# 0           3      309
# 1           5       42
# 2           1       24
# 3           2       20
# 4           7       18
# 5           6       14
# 6           4       12
#
# ...
